# %% [markdown]
# # **Instrument to Instrument (ITI) translation: Solar Orbiter/EUI/FSI-to-SDO/AIA**

# %% [markdown]
# ## Read The Docs
# For more information about the tool and background of the individual case studies see:
#
# [iti-documentation.rtfd.io](https://iti-documentation.readthedocs.io/en/latest/)

# %% [markdown]
# The Instrument-to-Instrument (ITI) translation tool can perform image domain translations between two different instruments. This allows ITI to be used for image enhancement, instrument intercalibration, and super-resolution observations in different scientific fields. For heliophysics, ITI has been applied to several instruments of various space-based and ground-based solar telescopes.
#
# This colab notebook provides an example of translation for the image enhancement case study by applying ITI for translation between the **SDO/HMI** instrument and **Hinode/SOT**. Here we super-resolve HMI observations with 4096x4096 pixels by a factor 4. The model was trained with observations from Hinode/SOT to infer the resolution increase.

# %% [markdown]
# ## Installation

# %%
# !pip install git+https://github.com/spaceml-org/InstrumentToInstrument.git@development
# !pip install lightning
# !pip install sunpy_soar
# !pip install sunpy
# Out:
# Collecting git+https://github.com/spaceml-org/InstrumentToInstrument.git@development
#   Cloning https://github.com/spaceml-org/InstrumentToInstrument.git (to revision development) to /private/var/folders/tj/7h3lqn950sv5k36g1yyl4vkr0000gn/T/pip-req-build-pin16jsd
#   Running command git clone --filter=blob:none --quiet https://github.com/spaceml-org/InstrumentToInstrument.git /private/var/folders/tj/7h3lqn950sv5k36g1yyl4vkr0000gn/T/pip-req-build-pin16jsd
#   Running command git checkout -b development --track origin/development
#   Switched to a new branch 'development'
#   Branch 'development' set up to track remote branch 'development' from 'origin'.
#   Resolved https://github.com/spaceml-org/InstrumentToInstrument.git to commit b083c705d463997caebf2df663d8774cbe569eda
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (2.2.2)
# Requirement already satisfied: sunpy>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (4.1.7)
# Requirement already satisfied: scikit-image in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (0.21.0)
# Requirement already satisfied: scikit-learn in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (1.3.2)
# Requirement already satisfied: tqdm in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (4.66.4)
# Requirement already satisfied: numpy in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (1.24.4)
# Requirement already satisfied: matplotlib in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (3.7.5)
# Requirement already satisfied: astropy in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (5.2.2)
# Requirement already satisfied: aiapy in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (0.7.4)
# Requirement already satisfied: drms in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (0.6.4)
# Requirement already satisfied: jupyter in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (1.0.0)
# Requirement already satisfied: sunpy_soar in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (1.8)
# Requirement already satisfied: lightning in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (2.3.0)
# Requirement already satisfied: google in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (3.0.0)
# Requirement already satisfied: google-cloud-storage in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (2.17.0)
# Requirement already satisfied: wandb in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from InstrumentToInstrument==0.1) (0.17.3)
# Requirement already satisfied: packaging>=19.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy>=2.0->InstrumentToInstrument==0.1) (24.0)
# Requirement already satisfied: parfive[ftp]>=1.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy>=2.0->InstrumentToInstrument==0.1) (2.1.0)
# Requirement already satisfied: pyerfa>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from astropy->InstrumentToInstrument==0.1) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from astropy->InstrumentToInstrument==0.1) (6.0.1)
# Requirement already satisfied: filelock in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch>=1.8->InstrumentToInstrument==0.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch>=1.8->InstrumentToInstrument==0.1) (4.12.1)
# Requirement already satisfied: sympy in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch>=1.8->InstrumentToInstrument==0.1) (1.12.1)
# Requirement already satisfied: networkx in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch>=1.8->InstrumentToInstrument==0.1) (3.1)
# Requirement already satisfied: jinja2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch>=1.8->InstrumentToInstrument==0.1) (3.1.4)
# Requirement already satisfied: fsspec in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch>=1.8->InstrumentToInstrument==0.1) (2024.6.0)
# Requirement already satisfied: pandas in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from drms->InstrumentToInstrument==0.1) (2.0.3)
# Requirement already satisfied: beautifulsoup4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google->InstrumentToInstrument==0.1) (4.12.3)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-cloud-storage->InstrumentToInstrument==0.1) (2.30.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-cloud-storage->InstrumentToInstrument==0.1) (2.19.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-cloud-storage->InstrumentToInstrument==0.1) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-cloud-storage->InstrumentToInstrument==0.1) (2.7.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-cloud-storage->InstrumentToInstrument==0.1) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-cloud-storage->InstrumentToInstrument==0.1) (1.5.0)
# Requirement already satisfied: notebook in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter->InstrumentToInstrument==0.1) (7.2.0)
# Requirement already satisfied: qtconsole in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter->InstrumentToInstrument==0.1) (5.5.2)
# Requirement already satisfied: jupyter-console in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter->InstrumentToInstrument==0.1) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter->InstrumentToInstrument==0.1) (7.16.4)
# Requirement already satisfied: ipykernel in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter->InstrumentToInstrument==0.1) (6.29.4)
# Requirement already satisfied: ipywidgets in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter->InstrumentToInstrument==0.1) (8.1.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning->InstrumentToInstrument==0.1) (0.11.3.post0)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning->InstrumentToInstrument==0.1) (1.4.0.post0)
# Requirement already satisfied: pytorch-lightning in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning->InstrumentToInstrument==0.1) (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from matplotlib->InstrumentToInstrument==0.1) (6.4.0)
# Requirement already satisfied: scipy>=1.8 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-image->InstrumentToInstrument==0.1) (1.10.1)
# Requirement already satisfied: imageio>=2.27 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-image->InstrumentToInstrument==0.1) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-image->InstrumentToInstrument==0.1) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-image->InstrumentToInstrument==0.1) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-image->InstrumentToInstrument==0.1) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-learn->InstrumentToInstrument==0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from scikit-learn->InstrumentToInstrument==0.1) (3.5.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (3.1.43)
# Requirement already satisfied: platformdirs in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (5.27.2)
# Requirement already satisfied: psutil>=5.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (5.9.8)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (2.7.0)
# Requirement already satisfied: setproctitle in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (1.3.3)
# Requirement already satisfied: setuptools in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from wandb->InstrumentToInstrument==0.1) (68.2.0)
# Requirement already satisfied: six>=1.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from docker-pycreds>=0.4.0->wandb->InstrumentToInstrument==0.1) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from fsspec->torch>=1.8->InstrumentToInstrument==0.1) (3.9.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->InstrumentToInstrument==0.1) (4.0.11)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->InstrumentToInstrument==0.1) (1.63.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->InstrumentToInstrument==0.1) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->InstrumentToInstrument==0.1) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->InstrumentToInstrument==0.1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->InstrumentToInstrument==0.1) (4.9)
# Requirement already satisfied: zipp>=3.1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->InstrumentToInstrument==0.1) (3.19.2)
# Requirement already satisfied: aioftp>=0.17.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from parfive[ftp]>=1.2.0->sunpy>=2.0->InstrumentToInstrument==0.1) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->InstrumentToInstrument==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->InstrumentToInstrument==0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->InstrumentToInstrument==0.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->InstrumentToInstrument==0.1) (2024.6.2)
# Requirement already satisfied: mpl-animators>=1.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy>=2.0->InstrumentToInstrument==0.1) (1.1.0)
# Requirement already satisfied: reproject in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy>=2.0->InstrumentToInstrument==0.1) (0.13.0)
# Requirement already satisfied: zeep>=3.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy>=2.0->InstrumentToInstrument==0.1) (4.2.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from beautifulsoup4->google->InstrumentToInstrument==0.1) (2.5)
# Requirement already satisfied: appnope in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipykernel->jupyter->InstrumentToInstrument==0.1) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipywidgets->jupyter->InstrumentToInstrument==0.1) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipywidgets->jupyter->InstrumentToInstrument==0.1) (3.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jinja2->torch>=1.8->InstrumentToInstrument==0.1) (2.1.5)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-console->jupyter->InstrumentToInstrument==0.1) (3.0.46)
# Requirement already satisfied: pygments in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-console->jupyter->InstrumentToInstrument==0.1) (2.18.0)
# Requirement already satisfied: bleach!=5.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (7.1.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbconvert->jupyter->InstrumentToInstrument==0.1) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from notebook->jupyter->InstrumentToInstrument==0.1) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from notebook->jupyter->InstrumentToInstrument==0.1) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from notebook->jupyter->InstrumentToInstrument==0.1) (4.2.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from notebook->jupyter->InstrumentToInstrument==0.1) (0.2.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from pandas->drms->InstrumentToInstrument==0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from pandas->drms->InstrumentToInstrument==0.1) (2024.1)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from qtconsole->jupyter->InstrumentToInstrument==0.1) (2.4.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sympy->torch>=1.8->InstrumentToInstrument==0.1) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8->InstrumentToInstrument==0.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8->InstrumentToInstrument==0.1) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8->InstrumentToInstrument==0.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8->InstrumentToInstrument==0.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8->InstrumentToInstrument==0.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch>=1.8->InstrumentToInstrument==0.1) (4.0.3)
# Requirement already satisfied: webencodings in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert->jupyter->InstrumentToInstrument==0.1) (0.5.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->InstrumentToInstrument==0.1) (5.0.1)
# Requirement already satisfied: backcall in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.2.0)
# Requirement already satisfied: decorator in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.19.1)
# Requirement already satisfied: pickleshare in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.7.5)
# Requirement already satisfied: stack-data in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (4.9.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->InstrumentToInstrument==0.1) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->InstrumentToInstrument==0.1) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->InstrumentToInstrument==0.1) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (4.22.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert->jupyter->InstrumentToInstrument==0.1) (2.19.1)
# Requirement already satisfied: wcwidth in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->InstrumentToInstrument==0.1) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage->InstrumentToInstrument==0.1) (0.6.0)
# Requirement already satisfied: isodate>=0.5.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy>=2.0->InstrumentToInstrument==0.1) (0.6.1)
# Requirement already satisfied: lxml>=4.6.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy>=2.0->InstrumentToInstrument==0.1) (5.2.2)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy>=2.0->InstrumentToInstrument==0.1) (1.0.0)
# Requirement already satisfied: requests-file>=1.5.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy>=2.0->InstrumentToInstrument==0.1) (2.1.0)
# Requirement already satisfied: astropy-healpix>=0.6 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (0.7)
# Requirement already satisfied: dask[array]>=2021.8 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (2023.5.0)
# Requirement already satisfied: cloudpickle in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (3.0.0)
# Requirement already satisfied: zarr in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (2.16.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (21.2.0)
# Requirement already satisfied: partd>=1.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from dask[array]>=2021.8->reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from dask[array]>=2021.8->reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (0.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->InstrumentToInstrument==0.1) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->InstrumentToInstrument==0.1) (0.2.2)
# Requirement already satisfied: asciitree in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zarr->reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (0.3.3)
# Requirement already satisfied: fasteners in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zarr->reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (0.19)
# Requirement already satisfied: numcodecs>=0.10.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zarr->reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (0.12.1)
# Requirement already satisfied: fqdn in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (1.5.1)
# Requirement already satisfied: isoduration in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (2.4)
# Requirement already satisfied: uri-template in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (1.13)
# Requirement already satisfied: locket in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from partd>=1.2.0->dask[array]>=2021.8->reproject->sunpy>=2.0->InstrumentToInstrument==0.1) (1.0.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (1.16.0)
# Requirement already satisfied: pycparser in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->InstrumentToInstrument==0.1) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->InstrumentToInstrument==0.1) (2.9.0.20240316)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: lightning in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (2.3.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]<2026.0,>=2022.5.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (2024.6.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (0.11.3.post0)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (1.24.4)
# Requirement already satisfied: packaging<25.0,>=20.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (24.0)
# Requirement already satisfied: torch<4.0,>=2.0.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (2.2.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (1.4.0.post0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (4.66.4)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (4.12.1)
# Requirement already satisfied: pytorch-lightning in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning) (2.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.9.5)
# Requirement already satisfied: setuptools in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from lightning-utilities<2.0,>=0.8.0->lightning) (68.2.0)
# Requirement already satisfied: filelock in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch<4.0,>=2.0.0->lightning) (3.15.4)
# Requirement already satisfied: sympy in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch<4.0,>=2.0.0->lightning) (1.12.1)
# Requirement already satisfied: networkx in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch<4.0,>=2.0.0->lightning) (3.1)
# Requirement already satisfied: jinja2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from torch<4.0,>=2.0.0->lightning) (3.1.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from jinja2->torch<4.0,>=2.0.0->lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sympy->torch<4.0,>=2.0.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.7)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sunpy_soar in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (1.8)
# Requirement already satisfied: sunpy[net]>=2.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy_soar) (4.1.7)
# Requirement already satisfied: astropy>=4.2.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (5.2.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (1.24.4)
# Requirement already satisfied: packaging>=19.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (24.0)
# Requirement already satisfied: parfive[ftp]>=1.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (2.1.0)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (4.12.3)
# Requirement already satisfied: drms>=0.6.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (0.6.4)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.32.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (4.66.4)
# Requirement already satisfied: zeep>=3.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy[net]>=2.1->sunpy_soar) (4.2.1)
# Requirement already satisfied: pyerfa>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from astropy>=4.2.1->sunpy[net]>=2.1->sunpy_soar) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from astropy>=4.2.1->sunpy[net]>=2.1->sunpy_soar) (6.0.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from beautifulsoup4>=4.8.0->sunpy[net]>=2.1->sunpy_soar) (2.5)
# Requirement already satisfied: pandas in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from drms>=0.6.1->sunpy[net]>=2.1->sunpy_soar) (2.0.3)
# Requirement already satisfied: aiohttp in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (3.9.5)
# Requirement already satisfied: aioftp>=0.17.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (0.22.3)
# Requirement already satisfied: six>=1.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.0->sunpy[net]>=2.1->sunpy_soar) (1.16.0)
# Requirement already satisfied: attrs>=17.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (23.2.0)
# Requirement already satisfied: isodate>=0.5.4 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (0.6.1)
# Requirement already satisfied: lxml>=4.6.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (5.2.2)
# Requirement already satisfied: platformdirs>=1.4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (4.2.2)
# Requirement already satisfied: requests>=2.7.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (1.0.0)
# Requirement already satisfied: requests-file>=1.5.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (2.1.0)
# Requirement already satisfied: pytz in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from requests>=2.7.0->zeep>=3.4.0->sunpy[net]>=2.1->sunpy_soar) (2024.6.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy[net]>=2.1->sunpy_soar) (4.0.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from pandas->drms>=0.6.1->sunpy[net]>=2.1->sunpy_soar) (2024.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sunpy in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (4.1.7)
# Requirement already satisfied: astropy>=4.2.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy) (5.2.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy) (1.24.4)
# Requirement already satisfied: packaging>=19.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy) (24.0)
# Requirement already satisfied: parfive[ftp]>=1.2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from sunpy) (2.1.0)
# Requirement already satisfied: pyerfa>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from astropy>=4.2.1->sunpy) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from astropy>=4.2.1->sunpy) (6.0.1)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from parfive[ftp]>=1.2.0->sunpy) (4.66.4)
# Requirement already satisfied: aiohttp in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from parfive[ftp]>=1.2.0->sunpy) (3.9.5)
# Requirement already satisfied: aioftp>=0.17.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from parfive[ftp]>=1.2.0->sunpy) (0.22.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from aiohttp->parfive[ftp]>=1.2.0->sunpy) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /Users/christophschirninger/PycharmProjects/ITI/venv/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->parfive[ftp]>=1.2.0->sunpy) (3.7)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Imports

# %%
from iti.download.download_hmi_continuum import HMIContinuumDownloader
from iti.translate import *
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ## Download data

# %% [markdown]
# We start by downloading FITS files from SDO/HMI continuum. ITI provides a download routines for multiple data sets, here we utilize the HMIContinuumDownloader. We download an observation from 2021-09-09.

# %%
fetcher = HMIContinuumDownloader(ds_path='hmi', email='chri.schirni@hotmail.de', num_worker_threads=4)
hmi_files = fetcher.fetchDates([datetime(2021, 9, 9, 15)])
print('downloaded:', hmi_files)
# Out:
# INFO:root:Fetch header information
# INFO:root:Download data
# downloaded: ['hmi/2021-09-09T15:00:00.fits']
# WARNING: SunpyMetadataWarning: The meta key cparms_sg000 is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key continuum_bzero is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key continuum_bscale is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key date__obs is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key crder1 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key crder2 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key csyser1 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key csyser2 has a NaN value, which is not valid in a FITS header, dropping from the FITS header [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key t_rec_epoch is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key t_rec_step is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key t_rec_unit is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]
# WARNING: SunpyMetadataWarning: The meta key t_rec_index is too long, dropping from the FITS header (maximum allowed key length is 8 characters). [sunpy.io._fits]

# %% [markdown]
# For later comparison we load the HMI FITS file as SunPy Map.

# %%
hmi_map = Map(hmi_files[0])
hmi_map.data[np.isnan(hmi_map.data)] = 0

# %% [markdown]
# The translator classes are the core element of the ITI translation. They follow the notation: InstrumentAToInstrumentB. For HMI files we need to translate the image in patches (patch_factor=3), otherwise we would exceed the memory.
#
# The first initialization of each translator triggers the download of the pre-trained model and stores it locally for later use.

# %%
translator = HMIToHinode(patch_factor=3)

# %% [markdown]
# The translate function starts the translation process of the HMI FITS files and returns a genartor object. This can be used to sequentially process the results. Here we only translate a single file and convert the generator object to a list.

# %%
iti_hmi_map = list(translator.translate(hmi_files))[0]

# %% [markdown]
# The result of the ITI translation is a SunPy map that stores all necessary coordinate information. We can compare this map to the original HMI observation.

# %%
fig, axs = plt.subplots(1, 2, subplot_kw={'projection': hmi_map},  figsize=(20, 10))
hmi_map.rotate().plot(axes=axs[0])
axs[0].set_title('Original - HMI')
iti_hmi_map.plot(axes=axs[1])
axs[1].set_title('ITI')
plt.show()
plt.close()
# Out:
# WARNING: SunpyUserWarning: The map world coordinate system (WCS) is different from the axes WCS. The map data axes may not correctly align with the coordinate axes. To automatically transform the data to the coordinate axes, specify `autoalign=True`. [sunpy.map.mapbase]
# WARNING:sunpy:SunpyUserWarning: The map world coordinate system (WCS) is different from the axes WCS. The map data axes may not correctly align with the coordinate axes. To automatically transform the data to the coordinate axes, specify `autoalign=True`.
